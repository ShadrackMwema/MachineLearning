# %%
#Pandas(DAta analysis)
import pandas as pd

url = '/home/shad/Downloads/blooth_sales_data.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#          name    birthday                       customer  \
# 0    Pasquale  1967-09-02                Electronics Inc
# 1       India  1968-12-13     Electronics Resource Group
# 2       Wayne  1992-09-10  East Application Contract Inc
# 3        Cori  1986-11-05              Signal Industries
# 4       Chang  1972-04-23          Star Alpha Industries
# ..        ...         ...                            ...
# 995     Ethan  1952-12-08         Application Industries
# 996   Rudolph  1959-10-15      Network Software West Inc
# 997  Annmarie  1982-06-04           Atlantic Corporation
# 998     Chang  1984-02-05      Venture Alpha Corporation
# 999     Ervin  1977-10-14                Provider Agency
#
#                       orderdate            product  units  unitprice
# 0    2016-07-17 13:48:03.156566    Thriller record      2      13.27
# 1    2016-07-06 13:48:03.156596            Corolla     26   24458.69
# 2    2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79
# ...

# %%
#Birthday and the name

df[['name', 'birthday']].head()
# Out:
#        name    birthday
# 0  Pasquale  1967-09-02
# 1     India  1968-12-13
# 2     Wayne  1992-09-10
# 3      Cori  1986-11-05
# 4     Chang  1972-04-23

# %%
#column 2 to 4
df.iloc[2:]
# Out:
#          name    birthday                           customer  \
# 2       Wayne  1992-09-10      East Application Contract Inc
# 3        Cori  1986-11-05                  Signal Industries
# 4       Chang  1972-04-23              Star Alpha Industries
# 5      Weldon  1953-03-17             Network Application Co
# 6        Sung  1977-10-23  Omega Pacific Future Incorporated
# ..        ...         ...                                ...
# 995     Ethan  1952-12-08             Application Industries
# 996   Rudolph  1959-10-15          Network Software West Inc
# 997  Annmarie  1982-06-04               Atlantic Corporation
# 998     Chang  1984-02-05          Venture Alpha Corporation
# 999     Ervin  1977-10-14                    Provider Agency
#
#                       orderdate            product  units  unitprice
# 2    2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79
# 3    2016-07-23 13:48:03.156638             iPhone     16     584.01
# ...

# %%
#columns unions select only the rows whoae unit value if less than 10
print(df.columns)

df[df["units"] > 10]
# Out:
# Index(['name', 'birthday', 'customer', 'orderdate', 'product', 'units',
#        'unitprice'],
#       dtype='object')
#          name    birthday                           customer  \
# 1       India  1968-12-13         Electronics Resource Group
# 2       Wayne  1992-09-10      East Application Contract Inc
# 3        Cori  1986-11-05                  Signal Industries
# 6        Sung  1977-10-23  Omega Pacific Future Incorporated
# 8     Cornell  1963-07-02     Technology Direct Star Limited
# ..        ...         ...                                ...
# 994    Maggie  1959-07-21          Hill People Industries Co
# 995     Ethan  1952-12-08             Application Industries
# 997  Annmarie  1982-06-04               Atlantic Corporation
# 998     Chang  1984-02-05          Venture Alpha Corporation
# 999     Ervin  1977-10-14                    Provider Agency
#
#                       orderdate            product  units  unitprice
# ...

# %%
df[(df['product'] == 'iPhone') & (df['units'] > 10)]
# Out:
#         name    birthday                       customer  \
# 3       Cori  1986-11-05              Signal Industries
# 23      Chet  1980-12-18     Vision Speed International
# 34    Rashad  1981-08-12   General Contract Corporation
# 55   Rudolph  1959-10-15      Network Software West Inc
# 93    Gracie  1978-05-07       Resource Virtual Limited
# ..       ...         ...                            ...
# 941     Lacy  1978-07-01                     Hill Group
# 964  Damaris  1984-06-01    North Innovation Vision Inc
# 972     Cori  1986-11-05              Signal Industries
# 980  Arnoldo  1992-05-25  Star General Architecture LLC
# 999    Ervin  1977-10-14                Provider Agency
#
#                       orderdate product  units  unitprice
# 3    2016-07-23 13:48:03.156638  iPhone     16     584.01
# 23   2016-07-15 13:48:03.157071  iPhone     44     500.83
# 34   2016-07-14 13:48:03.157283  iPhone     47     871.32
# ...

# %%
column_names = ['name', 'units']


sd = df.loc[:10, column_names] 


selected_data = sd[sd['units'] > 20]


print(selected_data)
# Out:
#        name  units
# 1     India     26
# 2     Wayne     41
# 6      Sung     25
# 8   Cornell     35
# 9     Ervin     24
# 10     Odis     27

# %%
#create random data that generates 1000 random number list
#create a new column "sales" in the sales_data
# put the number list in the sales column

# %%
import numpy as np

df['sales'] = np.random.uniform(20, 70, size=len(df))  # Use the length of the DataFrame to match the number of rows

# Display the first few rows to confirm the new column
print(df.head())
# Out:
#        name    birthday                       customer  \
# 0  Pasquale  1967-09-02                Electronics Inc
# 1     India  1968-12-13     Electronics Resource Group
# 2     Wayne  1992-09-10  East Application Contract Inc
# 3      Cori  1986-11-05              Signal Industries
# 4     Chang  1972-04-23          Star Alpha Industries
#
#                     orderdate            product  units  unitprice      sales  \
# 0  2016-07-17 13:48:03.156566    Thriller record      2      13.27  30.806569
# 1  2016-07-06 13:48:03.156596            Corolla     26   24458.69  45.211279
# 2  2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79  46.753660
# 3  2016-07-23 13:48:03.156638             iPhone     16     584.01  51.812144
# 4  2016-07-16 13:48:03.156657  Harry Potter book      4      25.69  68.530727
#
#       prices
# 0      26.54
# 1  635925.94
# 2     647.39
# 3    9344.16
# 4     102.76

# %%
# df = df.drop(columns=["sales"])

# %%
df
# Out:
#          name    birthday                       customer  \
# 0    Pasquale  1967-09-02                Electronics Inc
# 1       India  1968-12-13     Electronics Resource Group
# 2       Wayne  1992-09-10  East Application Contract Inc
# 3        Cori  1986-11-05              Signal Industries
# 4       Chang  1972-04-23          Star Alpha Industries
# ..        ...         ...                            ...
# 995     Ethan  1952-12-08         Application Industries
# 996   Rudolph  1959-10-15      Network Software West Inc
# 997  Annmarie  1982-06-04           Atlantic Corporation
# 998     Chang  1984-02-05      Venture Alpha Corporation
# 999     Ervin  1977-10-14                Provider Agency
#
#                       orderdate            product  units  unitprice  \
# 0    2016-07-17 13:48:03.156566    Thriller record      2      13.27
# 1    2016-07-06 13:48:03.156596            Corolla     26   24458.69
# 2    2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79
# ...

# %%
df["turnover"]=df["units"]*df["unitprice"]

# %%
df
# Out:
#          name    birthday                       customer  \
# 0    Pasquale  1967-09-02                Electronics Inc
# 1       India  1968-12-13     Electronics Resource Group
# 2       Wayne  1992-09-10  East Application Contract Inc
# 3        Cori  1986-11-05              Signal Industries
# 4       Chang  1972-04-23          Star Alpha Industries
# ..        ...         ...                            ...
# 995     Ethan  1952-12-08         Application Industries
# 996   Rudolph  1959-10-15      Network Software West Inc
# 997  Annmarie  1982-06-04           Atlantic Corporation
# 998     Chang  1984-02-05      Venture Alpha Corporation
# 999     Ervin  1977-10-14                Provider Agency
#
#                       orderdate            product  units  unitprice  \
# 0    2016-07-17 13:48:03.156566    Thriller record      2      13.27
# 1    2016-07-06 13:48:03.156596            Corolla     26   24458.69
# 2    2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79
# ...

# %%
df["turnover"].sum()
# Out:
# 57794302.12

# %%
df
# Out:
#          name    birthday                       customer  \
# 0    Pasquale  1967-09-02                Electronics Inc
# 1       India  1968-12-13     Electronics Resource Group
# 2       Wayne  1992-09-10  East Application Contract Inc
# 3        Cori  1986-11-05              Signal Industries
# 4       Chang  1972-04-23          Star Alpha Industries
# ..        ...         ...                            ...
# 995     Ethan  1952-12-08         Application Industries
# 996   Rudolph  1959-10-15      Network Software West Inc
# 997  Annmarie  1982-06-04           Atlantic Corporation
# 998     Chang  1984-02-05      Venture Alpha Corporation
# 999     Ervin  1977-10-14                Provider Agency
#
#                       orderdate            product  units  unitprice  \
# 0    2016-07-17 13:48:03.156566    Thriller record      2      13.27
# 1    2016-07-06 13:48:03.156596            Corolla     26   24458.69
# 2    2016-07-22 13:48:03.156618       Rubik’s Cube     41      15.79
# ...

# %%
column_names = ['product', 'turnover']


sd = df.loc[::, column_names] 
#output turnover for iphone

selected_data = sd[sd['product']== 'iPhone']


print(selected_data)
# Out:
#     product  turnover
# 3    iPhone   9344.16
# 23   iPhone  22036.52
# 34   iPhone  40952.04
# 55   iPhone   5796.44
# 68   iPhone   3249.24
# ..      ...       ...
# 946  iPhone   6818.40
# 964  iPhone   7708.87
# 972  iPhone  19474.20
# 980  iPhone  16697.01
# 999  iPhone  25889.37
#
# [103 rows x 2 columns]

# %%
df["birthday"].describe()
# Out:
# count           1000
# unique           284
# top       1986-11-05
# freq              10
# Name: birthday, dtype: object

# %%
#delete som efiles save it as sales_data_2 csv
#run .info
#check different ways of filling missong file data
df.fillna(40,inplace=True)

df.dropna(40,inplace=True)
#changine the date using date header, delimiter,header, conditions, slicing and indexing,
#statistics:sum, median, how to handle missing values ,
